# %%
import pandas as pd
import os
import time
from tqdm import tqdm
import shutil
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add
path="captures_IoT-Sentinel"
files_add=find_the_way(path,'.pcap')
files_add
# Out:
# ['captures_IoT-Sentinel\\Aria\\Setup-A-1-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-2-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-3-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-4-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-5-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-1-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-10-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-11-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-12-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-13-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-14-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-15-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-2-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-3-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-4-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-5-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-6-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-7-STA.pcap',
# ...

# %%
MAC_list={# IoT devices captures MAC and Device names
'00:17:88:24:76:ff': 'Hue-Device',
 '00:1a:22:03:cb:be': 'MAXGateway',
 '00:1a:22:05:c4:2e': 'HomeMaticPlug',
 '00:24:e4:24:80:2a': 'Withings',
 '00:b5:6d:06:08:ba': 'unknown',
 '1c:5f:2b:aa:fd:4e': 'D-LinkDevice',
 '20:f8:5e:ca:91:52': 'Aria',
 '24:77:03:7c:ea:dc': 'unknown',
 '28:b2:bd:c3:41:79': 'unknown',
 '38:0b:40:ef:85:41': 'unknown',

 '50:c7:bf:00:c7:03': 'TP-LinkPlugHS110',
 '50:c7:bf:00:fc:a3': 'TP-LinkPlugHS100',
 '3c:49:37:03:17:db': 'EdnetCam',
 '3c:49:37:03:17:f0': 'EdnetCam',
 '5c:cf:7f:06:d9:02': 'iKettle2',
 '5c:cf:7f:07:ae:fb': 'SmarterCoffee',
 '6c:72:20:c5:17:5a': 'D-LinkWaterSensor',
 '74:da:38:23:22:7b': 'EdimaxPlug2101W',
 '74:da:38:4a:76:49': 'EdimaxPlug1101W',
 '74:da:38:80:79:fc': 'EdimaxCam',
 '74:da:38:80:7a:08': 'EdimaxCam',
 '84:18:26:7b:5f:6b': 'Lightify',
 '90:8d:78:a8:e1:43': 'D-LinkSensor',
 '90:8d:78:a9:3d:6f': 'D-LinkSwitch',
 '90:8d:78:dd:0d:60': 'D-LinkSiren',
 '94:10:3e:34:0c:b5': 'WeMoSwitch',
 '94:10:3e:35:01:c1': 'WeMoSwitch',
 '94:10:3e:41:c2:05': 'WeMoInsightSwitch',
 '94:10:3e:42:80:69': 'WeMoInsightSwitch',
 '94:10:3e:cd:37:65': 'WeMoLink',
 'ac:cf:23:62:3c:6e': 'EdnetGateway',
 'b0:c5:54:1c:71:85': 'D-LinkDayCam',
 'b0:c5:54:25:5b:0e': 'D-LinkCam',
 'bc:f5:ac:f4:c0:9d': 'unknown'}

# %% [markdown]
# # PCAP2CSV

# %%
from scapy.all import*

# %%
import math
import pandas as pd
import os
import numpy as np

# %%
def folder(f_name): #this function creates a folder.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
def flag_fixer(file):

    IP_flags = {'0': 1, '<Flag 0 ()>': 2, '<Flag 2 (DF)>': 3, '<Flag 1 (MF)>': 4,'<Flag 3 (MF+DF)>':5,
     '<Flag 4 (evil)>':6,
     '<Flag 5 (MF+evil)>':7,
     '<Flag 6 (DF+evil)>':8,
     '<Flag 7 (MF+DF+evil)>':9,
     '<Flag 3 (MF+DF)>':10,
     '<Flag 4 (evil)>':11,
     '<Flag 5 (MF+evil)>':12,
     '<Flag 6 (DF+evil)>':13,
     '<Flag 7 (MF+DF+evil)>':14,
     '<Flag 3 (MF+DF)>':15,
     '<Flag 4 (evil)>':16,
     '<Flag 5 (MF+evil)>':17,
     '<Flag 6 (DF+evil)>':18,
     '<Flag 7 (MF+DF+evil)>':19,
     '<Flag 3 (MF+DF)>':20,
     '<Flag 4 (evil)>':21,
     '<Flag 5 (MF+evil)>':22,
     '<Flag 6 (DF+evil)>':23,
     '<Flag 7 (MF+DF+evil)>':24,
     '<Flag 3 (MF+DF)>':25,
     '<Flag 4 (evil)>':26,
     '<Flag 5 (MF+evil)>':27,
     '<Flag 6 (DF+evil)>':28,
     '<Flag 7 (MF+DF+evil)>':29,
     '<Flag 3 (MF+DF)>':30,
     '<Flag 4 (evil)>':31,
     '<Flag 5 (MF+evil)>':32,
     '<Flag 6 (DF+evil)>':33,
     '<Flag 7 (MF+DF+evil)>':34,
     '<Flag 3 (MF+DF)>':35,
     '<Flag 4 (evil)>':36,
     '<Flag 5 (MF+evil)>':37,
     '<Flag 6 (DF+evil)>':38,
     '<Flag 7 (MF+DF+evil)>':39,
     '<Flag 3 (MF+DF)>':40,
     '<Flag 4 (evil)>':41,
     '<Flag 5 (MF+evil)>':42,
     '<Flag 6 (DF+evil)>':43,
     '<Flag 7 (MF+DF+evil)>':44}
  
    BOOTP_flags = {'0': 1, '<Flag 0 ()>': 2, '<Flag 32768 (B)>': 3, 0: 1}
    

    df=pd.read_csv(file)
    
    
    df["IP_flags"]=df["IP_flags"].map(IP_flags.get)

    df["BOOTP_flags"]=df["BOOTP_flags"].map(BOOTP_flags.get)

    
    #df=df.replace({"IP_flags": IP_flags})
    #df=df.replace({"TCP_flags": TCP_flags})
    #df=df.replace({"BOOTP_flags": BOOTP_flags})
    #df=df.replace({"Protocol": Protocol})
    #df=df.replace({"Label": label})
    df.to_csv(file,index=None)

# %%
def shannon(data):
    LOG_BASE = 2
   # We determine the frequency of each byte
   # in the dataset and if this frequency is not null we use it for the
   # entropy calculation
    dataSize = len(data)
    ent = 0.0
    freq={} 
    for c in data:
        if c in freq:
            freq[c] += 1
        else:
            freq[c] = 1
   # to determine if each possible value of a byte is in the list
    for key in freq.keys():
        f = float(freq[key])/dataSize
        if f > 0: # to avoid an error for log(0)
            ent = ent + f * math.log(f, LOG_BASE)
    return -ent

def pre_entropy(payload):
    
    characters=[]
    for i in payload:
            characters.append(i)
    return shannon(characters)

# %%
def port_class(port):
    port_list=[0,53,67,68,80,123,443,1900,5353,49153]# private port list (0-Reserved,53-DNS, 67-BOOTP server, 68-BOOTP client...)
    if port in port_list: #Is the port number in the list?
        return port_list.index(port)+1 # return the port's index number in the list (actually with index+1)
    elif 0 <= port <= 1023: # return 11 if the port number is in the range 0 :1023
        return 11
    elif  1024 <= port <= 49151 : # return 12 if the port number is in the range 1024:49151
        return 12
    elif 49152 <=port <= 65535 :# return 13 if the port number is in the range 49152:65535
        return 13
    else:# return 0 if no previous conditions are met
        return 0
    
    
def port_1023(port):
    if 0 <= port <= 1023:
        return port
    elif  1024 <= port <= 49151 :
        return 2
    elif 49152 <=port <= 65535 :
        return 3
    else:
        return 0

# %%
header="ts,Ether_dst,Ether_src,IP_src,IP_dst,pck_size,Ether_type,LLC_dsap,LLC_ssap,LLC_ctrl,EAPOL_version,EAPOL_type,EAPOL_len,IP_version,IP_ihl,IP_tos,IP_len,IP_flags,IP_Z,IP_MF,IP_id,IP_chksum,IP_DF,IP_frag,IP_ttl,IP_proto,IP_options,ICMP_type,ICMP_code,ICMP_chksum,ICMP_id,ICMP_seq,ICMP_ts_ori,ICMP_ts_rx,ICMP_ts_tx,ICMP_ptr,ICMP_reserved,ICMP_length,ICMP_nexthopmtu,ICMP_unused,TCP_seq,TCP_ack,TCP_dataofs,TCP_reserved,TCP_flags,TCP_FIN,TCP_SYN,TCP_RST,TCP_PSH,TCP_ACK,TCP_URG,TCP_ECE,TCP_CWR,TCP_window,TCP_chksum,TCP_urgptr,TCP_options,UDP_len,UDP_chksum,DHCP_options,BOOTP_op,BOOTP_htype,BOOTP_hlen,BOOTP_hops,BOOTP_xid,BOOTP_secs,BOOTP_flags,BOOTP_sname,BOOTP_file,BOOTP_options,DNS_length,DNS_id,DNS_qr,DNS_opcode,DNS_aa,DNS_tc,DNS_rd,DNS_ra,DNS_z,DNS_ad,DNS_cd,DNS_rcode,DNS_qdcount,DNS_ancount,DNS_nscount,DNS_arcount,sport_class,dport_class,sport23,dport23,sport_bare,dport_bare,TCP_sport,TCP_dport,UDP_sport,UDP_dport,payload_bytes,entropy,MAC,Label\n"

#header="pck_size,Ether_type,LLC_dsap,LLC_ssap,LLC_ctrl,EAPOL_version,EAPOL_type,EAPOL_len,IP_version,IP_ihl,IP_tos,IP_len,IP_flags,IP_frag,IP_ttl,IP_proto,IP_options,IP_add_count,ICMP_type,ICMP_code,ICMP_seq,ICMP_ts_ori,ICMP_ts_rx,ICMP_ts_tx,ICMP_gw,ICMP_ptr,ICMP_reserved,ICMP_length,ICMP_nexthopmtu,ICMP_unused,TCP_dataofs,TCP_reserved,TCP_flags,TCP_window,TCP_urgptr,UDP_len,BOOTP_op,BOOTP_htype,BOOTP_hlen,BOOTP_hops,BOOTP_secs,BOOTP_flags,DNS_length,DNS_qr,DNS_opcode,DNS_aa,DNS_tc,DNS_rd,DNS_ra,DNS_z,DNS_ad,DNS_cd,DNS_rcode,DNS_qdcount,DNS_ancount,DNS_nscount,DNS_arcount,sport,dport,entropy,Label,MAC\n"

# %%
#flags
#TCP
FIN = 0x01
SYN = 0x02
RST = 0x04
PSH = 0x08
ACK = 0x10
URG = 0x20
ECE = 0x40
CWR = 0x80
#IP
Z = 0x00
MF= 0x01
DF= 0x02

# %%
subfolders={'Aria':'Aria',
'D-LinkCam':'D-LinkCam',
'D-LinkDayCam':'D-LinkDayCam',
'D-LinkDoorSensor':'D-LinkDoorSensor',
'D-LinkHomeHub':'D-LinkHomeHub',
'D-LinkSensor':'D-LinkSensor',
'D-LinkSiren':'D-LinkSiren',
'D-LinkSwitch':'D-LinkSwitch',
'D-LinkWaterSensor':'D-LinkWaterSensor',
'EdimaxCam1':'EdimaxCam',
'EdimaxCam2':'EdimaxCam',
'EdimaxPlug1101W':'EdimaxPlug1101W',
'EdimaxPlug2101W':'EdimaxPlug2101W',
'EdnetCam1':'EdnetCam',
'EdnetCam2':'EdnetCam',
'EdnetGateway':'EdnetGateway',
'HomeMaticPlug':'HomeMaticPlug',
'HueBridge':'HueBridge',
'HueSwitch':'HueSwitch',
'iKettle2':'iKettle2',
'Lightify':'Lightify',
'MAXGateway':'MAXGateway',
'SmarterCoffee':'SmarterCoffee',
'TP-LinkPlugHS100':'TP-LinkPlugHS100',
'TP-LinkPlugHS110':'TP-LinkPlugHS110',
'WeMoInsightSwitch':'WeMoInsightSwitch',
'WeMoInsightSwitch2':'WeMoInsightSwitch',
'WeMoLink':'WeMoLink',
'WeMoSwitch':'WeMoSwitch',
'WeMoSwitch2':'WeMoSwitch',
'Withings':'Withings'}

# %%
files_add
# Out:
# ['captures_IoT-Sentinel\\Aria\\Setup-A-1-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-2-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-3-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-4-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-A-5-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-1-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-10-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-11-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-12-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-13-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-14-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-15-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-2-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-3-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-4-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-5-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-6-STA.pcap',
#  'captures_IoT-Sentinel\\Aria\\Setup-C-7-STA.pcap',
# ...

# %% [markdown]
# # Individual paket pased faetures

# %%
outputfolder="FE"
folder(outputfolder)




for sayac,i in enumerate (tqdm(files_add)):
    #print(f"{sayac+1}/{len(files_add)}-{i}")
    file_list=[i]    
    for isim in file_list:
    
        filename=isim.replace(".pcap","_FE.csv")
        ths = open(filename, "w")
        ths.write(header)  
 
    
    
        pkt = rdpcap(isim)
        for j in (pkt):
            
            if j.haslayer(ARP):
                continue
            else:
                ts=float(j.time)
                try:pck_size=j.len
                except:pck_size=0
                if j.haslayer(Ether):


                    Ether_dst=j[Ether].dst#Ether_adresses.index(j[Ether].dst)+1
                    Ether_src=j[Ether].src#Ether_adj[Ether].dstresses.index(j[Ether].src)+1


                    Ether_type=j[Ether].type
                else:
                    Ether_dst=0
                    Ether_src=0
                    Ether_type=0


                if j.haslayer(ARP):
                    ARP_hwtype=j[ARP].hwtype
                    ARP_ptype=j[ARP].ptype
                    ARP_hwlen=j[ARP].hwlen
                    ARP_plen=j[ARP].plen
                    ARP_op=j[ARP].op


                    ARP_hwsrc=j[ARP].hwsrc
                    ARP_psrc=j[ARP].psrc
                    ARP_hwdst=j[ARP].hwdst
                    ARP_pdst=j[ARP].pdst




                    ARP_hwsrc=j[ARP].hwsrc#Ether_adresses.index(j[ARP].hwsrc)+1
                    ARP_psrc=j[ARP].psrc#IP_adresses.index(j[ARP].psrc)+1
                    ARP_hwdst=j[ARP].hwdst#Ether_adresses.index(j[ARP].hwdst)+1
                    ARP_pdst=j[ARP].pdst#IP_adresses.index(j[ARP].pdst)+1


                else:
                    ARP_hwtype=0
                    ARP_ptype=0
                    ARP_hwlen=0
                    ARP_plen=0
                    ARP_op=0
                    ARP_hwsrc=0
                    ARP_psrc=0
                    ARP_hwdst=0
                    ARP_pdst=0            


                if j.haslayer(LLC):
                    LLC_dsap=j[LLC].dsap
                    LLC_ssap=j[LLC].ssap
                    LLC_ctrl=j[LLC].ctrl
                else:
                    LLC_dsap=0
                    LLC_ssap=0
                    LLC_ctrl=0            



                if j.haslayer(EAPOL):
                    EAPOL_version=j[EAPOL].version
                    EAPOL_type=j[EAPOL].type
                    EAPOL_len=j[EAPOL].len

                else:
                    EAPOL_version=0
                    EAPOL_type=0
                    EAPOL_len=0            


                if j.haslayer(IP):

                    IP_Z = 0
                    IP_MF= 0
                    IP_DF= 0

                    IP_version=j[IP].version
                    IP_ihl=j[IP].ihl
                    IP_tos=j[IP].tos
                    IP_len=j[IP].len
                    IP_id=j[IP].id
                    IP_flags=j[IP].flags

                    IP_frag=j[IP].frag
                    IP_ttl=j[IP].ttl
                    IP_proto=j[IP].proto
                    IP_chksum=j[IP].chksum


                    #if j[IP].options!=0:
                    IP_options=j[IP].options
                    if "IPOption_Router_Alert"   in str(IP_options):
                        IP_options=1
                    else:IP_options=0



                    #if IP_flags not in ipf: ipf.append(IP_flags)

                    if IP_flags & Z:IP_Z = 1
                    if IP_flags & MF:IP_MF = 1
                    if IP_flags & DF:IP_DF = 1
                    #if "Flag" in str(IP_flags):
                        #IP_flags=str(IP_flags)
                        #temp=IP_flags.find("(")
                        #IP_flags=int(IP_flags[6:temp-1])




                    IP_src=j[IP].src#IP_adresses.index(j[IP].src)+1
                    IP_dst=j[IP].dst#IP_adresses.index(j[IP].dst)+1                



                else:
                    IP_Z = 0
                    IP_MF= 0
                    IP_DF= 0

                    IP_version=0
                    IP_ihl=0
                    IP_tos=0
                    IP_len=0
                    IP_id=0
                    IP_flags=0
                    IP_frag=0
                    IP_ttl=0
                    IP_proto=0
                    IP_chksum=0
                    IP_src=0
                    IP_dst=0
                    IP_options=0
                    IP_add_count=0            

                if j.haslayer(ICMP):
                    ICMP_type=j[ICMP].type
                    ICMP_code=j[ICMP].code
                    ICMP_chksum=j[ICMP].chksum
                    ICMP_id=j[ICMP].id
                    ICMP_seq=j[ICMP].seq
                    ICMP_ts_ori=j[ICMP].ts_ori
                    ICMP_ts_rx=j[ICMP].ts_rx
                    ICMP_ts_tx=j[ICMP].ts_tx
                    ICMP_gw=j[ICMP].gw
                    ICMP_ptr=j[ICMP].ptr
                    ICMP_reserved=j[ICMP].reserved
                    ICMP_length=j[ICMP].length
                    ICMP_addr_mask=j[ICMP].addr_mask
                    ICMP_nexthopmtu=j[ICMP].nexthopmtu
                    ICMP_unused=j[ICMP].unused
                else:
                    ICMP_type=0
                    ICMP_code=0
                    ICMP_chksum=0
                    ICMP_id=0
                    ICMP_seq=0
                    ICMP_ts_ori=0
                    ICMP_ts_rx=0
                    ICMP_ts_tx=0
                    ICMP_gw=0
                    ICMP_ptr=0
                    ICMP_reserved=0
                    ICMP_length=0
                    ICMP_addr_mask=0
                    ICMP_nexthopmtu=0
                    ICMP_unused=0




                if j.haslayer(TCP):
                    TCP_FIN = 0
                    TCP_SYN = 0
                    TCP_RST = 0
                    TCP_PSH = 0
                    TCP_ACK = 0
                    TCP_URG = 0
                    TCP_ECE = 0
                    TCP_CWR = 0
                    TCP_sport=j[TCP].sport
                    TCP_dport=j[TCP].dport
                    TCP_seq=j[TCP].seq
                    TCP_ack=j[TCP].ack
                    TCP_dataofs=j[TCP].dataofs
                    TCP_reserved=j[TCP].reserved
                    TCP_flags=j[TCP].flags

                    TCP_window=j[TCP].window
                    TCP_chksum=j[TCP].chksum
                    TCP_urgptr=j[TCP].urgptr
                    TCP_options=j[TCP].options
                    TCP_options= str(TCP_options).replace(",","-")
                    if TCP_options!="0":
                        TCP_options=1
                    else:
                        TCP_options=0




                    #if TCP_flags not in tcpf:
                        #tcpf.append(TCP_flags)
                    #print(TCP_options)
                    if TCP_flags & FIN:TCP_FIN = 1
                    if TCP_flags & SYN:TCP_SYN = 1
                    if TCP_flags & RST:TCP_RST = 1
                    if TCP_flags & PSH:TCP_PSH = 1
                    if TCP_flags & ACK:TCP_ACK = 1
                    if TCP_flags & URG:TCP_URG = 1
                    if TCP_flags & ECE:TCP_ECE = 1
                    if TCP_flags & CWR:TCP_CWR = 1   
                    #print(TCP_flags)
                    #if "Flag" in str(TCP_flags):
                        #TCP_flags=str(TCP_flags)
                        #temp=TCP_flags.find("(")
                        #TCP_flags=int(TCP_flags[6:temp-1])




                else:
                    TCP_sport=0
                    TCP_dport=0
                    TCP_seq=0
                    TCP_ack=0
                    TCP_dataofs=0
                    TCP_reserved=0
                    TCP_flags=0
                    TCP_window=0
                    TCP_chksum=0
                    TCP_urgptr=0
                    TCP_options=0
                    TCP_options=0
                    TCP_FIN = 0
                    TCP_SYN = 0
                    TCP_RST = 0
                    TCP_PSH = 0
                    TCP_ACK = 0
                    TCP_URG = 0
                    TCP_ECE = 0
                    TCP_CWR = 0


                if j.haslayer(UDP):
                    UDP_sport=j[UDP].sport
                    UDP_dport=j[UDP].dport
                    UDP_len=j[UDP].len
                    UDP_chksum=j[UDP].chksum
                else:
                    UDP_sport=0
                    UDP_dport=0
                    UDP_len=0
                    UDP_chksum=0





                if j.haslayer(DHCP):
                    DHCP_options=str(j[DHCP].options)
                    DHCP_options=DHCP_options.replace(",","-")
                    if "message" in DHCP_options:
                        x = DHCP_options.find(")")
                        DHCP_options=int(DHCP_options[x-1])

                else:
                    DHCP_options=0            


                if j.haslayer(BOOTP):
                    BOOTP_op=j[BOOTP].op
                    BOOTP_htype=j[BOOTP].htype
                    BOOTP_hlen=j[BOOTP].hlen
                    BOOTP_hops=j[BOOTP].hops
                    BOOTP_xid=j[BOOTP].xid
                    BOOTP_secs=j[BOOTP].secs
                    BOOTP_flags=j[BOOTP].flags
                    #if "Flag" in str(BOOTP_flags):BOOTP_flags=str(BOOTP_flags)temp=BOOTP_flags.find("(") BOOTP_flags=int(BOOTP_flags[6:temp-1])
                    BOOTP_ciaddr=j[BOOTP].ciaddr
                    BOOTP_yiaddr=j[BOOTP].yiaddr
                    BOOTP_siaddr=j[BOOTP].siaddr
                    BOOTP_giaddr=j[BOOTP].giaddr
                    BOOTP_chaddr=j[BOOTP].chaddr
                    BOOTP_sname=str(j[BOOTP].sname)
                    if BOOTP_sname!="0":
                        BOOTP_sname=1
                    else:
                        BOOTP_sname=0
                    BOOTP_file=str(j[BOOTP].file)
                    if BOOTP_file!="0":
                        BOOTP_file=1
                    else:
                        BOOTP_file=0

                    BOOTP_options=str(j[BOOTP].options)
                    BOOTP_options=BOOTP_options.replace(",","-")
                    if BOOTP_options!="0":
                        BOOTP_options=1
                    else:
                        BOOTP_options=0
                else:
                    BOOTP_op=0
                    BOOTP_htype=0
                    BOOTP_hlen=0
                    BOOTP_hops=0
                    BOOTP_xid=0
                    BOOTP_secs=0
                    BOOTP_flags=0
                    BOOTP_ciaddr=0
                    BOOTP_yiaddr=0
                    BOOTP_siaddr=0
                    BOOTP_giaddr=0
                    BOOTP_chaddr=0
                    BOOTP_sname=0
                    BOOTP_file=0
                    BOOTP_options=0






                if j.haslayer(DNS):
                    DNS_length=j[DNS].length
                    DNS_id=j[DNS].id
                    DNS_qr=j[DNS].qr
                    DNS_opcode=j[DNS].opcode
                    DNS_aa=j[DNS].aa
                    DNS_tc=j[DNS].tc
                    DNS_rd=j[DNS].rd
                    DNS_ra=j[DNS].ra
                    DNS_z=j[DNS].z
                    DNS_ad=j[DNS].ad
                    DNS_cd=j[DNS].cd
                    DNS_rcode=j[DNS].rcode
                    DNS_qdcount=j[DNS].qdcount
                    DNS_ancount=j[DNS].ancount
                    DNS_nscount=j[DNS].nscount
                    DNS_arcount=j[DNS].arcount
                    DNS_qd=str(j[DNS].qd).replace(",","-")
                    if DNS_qd!="0":
                        DNS_qd=1
                    else:
                        DNS_qd=0
                    DNS_an=str(j[DNS].an).replace(",","-")
                    if DNS_an!="0":
                        DNS_an=1
                    else:
                        DNS_an=0
                    DNS_ns=str(j[DNS].ns).replace(",","-")
                    if DNS_ns!="0":
                        DNS_ns=1
                    else:
                        DNS_ns=0
                    DNS_ar=str(j[DNS].ar).replace(",","-")
                    if DNS_ar!="0":
                        DNS_ar=1
                    else:
                        DNS_ar=0
                else:
                    DNS_length=0
                    DNS_id=0
                    DNS_qr=0
                    DNS_opcode=0
                    DNS_aa=0
                    DNS_tc=0
                    DNS_rd=0
                    DNS_ra=0
                    DNS_z=0
                    DNS_ad=0
                    DNS_cd=0
                    DNS_rcode=0
                    DNS_qdcount=0
                    DNS_ancount=0
                    DNS_nscount=0
                    DNS_arcount=0
                    DNS_qd=0
                    DNS_an=0
                    DNS_ns=0
                    DNS_ar=0





                pdata=[]
                if "TCP" in j:            
                    pdata = (j[TCP].payload)
                if "Raw" in j:
                    pdata = (j[Raw].load)
                elif "UDP" in j:            
                    pdata = (j[UDP].payload)
                elif "ICMP" in j:            
                    pdata = (j[ICMP].payload)
                pdata=list(memoryview(bytes(pdata)))            

                if pdata!=[]:
                    entropy=shannon(pdata)        
                else:
                    entropy=0
                payload_bytes=len(pdata)

                sport_class=port_class(TCP_sport+UDP_sport)
                dport_class=port_class(TCP_dport+UDP_dport)
                sport23=port_1023(TCP_sport+UDP_sport)
                dport23=port_1023(TCP_dport+UDP_dport)
                sport_bare=TCP_sport+UDP_sport
                dport_bare=TCP_dport+UDP_dport#port_class(TCP_dport+UDP_dport)


                Mac=j.src             




                line=[ts,
                      Ether_dst,
                Ether_src,
                IP_src,
                IP_dst,
                pck_size,
                Ether_type,
                LLC_dsap,
                LLC_ssap,
                LLC_ctrl,
                EAPOL_version,
                EAPOL_type,
                EAPOL_len,
                IP_version,
                IP_ihl,
                IP_tos,
                IP_len,
                IP_flags,
                IP_Z,
                IP_MF,
                IP_id,
                IP_chksum,
                IP_DF  ,
                IP_frag,
                IP_ttl,
                IP_proto,
                IP_options,
                ICMP_type,
                ICMP_code,
                ICMP_chksum,
                ICMP_id,
                ICMP_seq,
                ICMP_ts_ori,
                ICMP_ts_rx,
                ICMP_ts_tx,
                ICMP_ptr,
                ICMP_reserved,
                ICMP_length,
                #ICMP_addr_mask,
                ICMP_nexthopmtu,
                ICMP_unused,
                TCP_seq,
                TCP_ack,
                TCP_dataofs,
                TCP_reserved,
                TCP_flags,
                TCP_FIN,
                TCP_SYN,
                TCP_RST,
                TCP_PSH,
                TCP_ACK,
                TCP_URG,
                TCP_ECE,
                TCP_CWR   ,
                TCP_window,
                TCP_chksum,
                TCP_urgptr,
                TCP_options,
                UDP_len,
                UDP_chksum,
                DHCP_options,
                BOOTP_op,
                BOOTP_htype,
                BOOTP_hlen,
                BOOTP_hops,
                BOOTP_xid,
                BOOTP_secs,
                BOOTP_flags,
                BOOTP_sname,
                BOOTP_file,
                BOOTP_options,
                DNS_length,
                DNS_id,
                DNS_qr,
                DNS_opcode,
                DNS_aa,
                DNS_tc,
                DNS_rd,
                DNS_ra,
                DNS_z,
                DNS_ad,
                DNS_cd,
                DNS_rcode,
                DNS_qdcount,
                DNS_ancount,
                DNS_nscount,
                DNS_arcount,
                sport_class,
                dport_class,
                sport23,
                dport23,
                sport_bare,
                dport_bare,
                TCP_sport,
                TCP_dport,
                UDP_sport,
                UDP_dport, 
                payload_bytes,
                entropy,Mac]

                #print(line)
                line=str(line).replace("[","")
                line=str(line).replace("]","")
                #line=str(line).replace("\',","-")
                line=str(line).replace(", ",",")
                line=str(line).replace("\'","")
                line=str(line).replace("None","0")

                if Mac in ["1c:5f:2b:aa:fd:4e","00:17:88:24:76:ff"]:
                    Label=i.split("\\")[1]
                    #print(Label)
                else:
                    if Mac in MAC_list:
                        Label=MAC_list[Mac]
                    else:
                        Label=Mac
                    

                ths.write(str(line)+f",{Label}\n")  

                #else:print(line)


        ths.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 550/550 [02:56<00:00,  3.12it/s]

# %%
files_add=find_the_way(path,'.csv')
#files_add

# %%
train=['captures_IoT-Sentinel/Aria/Setup-A-1-STA_FE.csv',
       'captures_IoT-Sentinel/WeMoLink/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-10-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-11-STA_FE.csv',
       'captures_IoT-Sentinel/Lightify/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-12-STA_FE.csv',
       'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-4-STA_FE.csv',
       'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-4-STA_FE.csv',
       'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-A-1-STA_FE.csv',
       'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-18-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-19-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-B-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-B-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-B-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-B-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-B-5-STA_FE.csv',
       'captures_IoT-Sentinel/D-LinkSiren/Setup-C-18-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-19-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-16-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-17-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-18-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-14-STA_FE.csv',
       'captures_IoT-Sentinel/EdnetGateway/Setup-C-17-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-18-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-3-STA_FE.csv',
       'captures_IoT-Sentinel/EdnetCam1/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam1/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-16-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-17-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-18-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-16-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-17-STA_FE.csv', 
       'captures_IoT-Sentinel/iKettle2/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-10-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-11-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-12-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-13-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-14-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-15-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-2-STA_FE.csv',
       'captures_IoT-Sentinel/HueBridge/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-10-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-8-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-A-9-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-18-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-12-STA_FE.csv',
       'captures_IoT-Sentinel/SmarterCoffee/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-10-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-11-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-12-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-13-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-14-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-15-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-13-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-14-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-15-STA_FE.csv',
       'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-A-3-STA_FE.csv', 
       'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-10-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-8-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-A-9-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-1-STA_FE.csv', 
       'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-10-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-11-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-8-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-A-9-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-13-STA_FE.csv',
       'captures_IoT-Sentinel/Withings/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-16-STA_FE.csv', 
       'captures_IoT-Sentinel/MAXGateway/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-8-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-A-9-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-17-STA_FE.csv', 
       'captures_IoT-Sentinel/WeMoSwitch/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-10-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-8-STA_FE.csv', 
       'captures_IoT-Sentinel/D-LinkCam/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-B-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-B-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-B-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-B-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-B-5-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-A-9-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-2-STA_FE.csv']

# %%
validation=[ 'captures_IoT-Sentinel/Aria/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-2-STA_FE.csv', 
            'captures_IoT-Sentinel/EdnetCam1/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-C-3-STA_FE.csv',
            'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-16-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-17-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam1/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-A-2-STA_FE.csv', 
            'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-4-STA_FE.csv', 
            'captures_IoT-Sentinel/Withings/Setup-C-18-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-19-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-4-STA_FE.csv', 
            'captures_IoT-Sentinel/WeMoSwitch/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch2/Setup-C-1-STA_FE.csv', 
            'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-2-STA_FE.csv',
            'captures_IoT-Sentinel/iKettle2/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-8-STA_FE.csv',
            'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-19-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-20-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-3-STA_FE.csv',
            'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-C-12-STA_FE.csv', 
            'captures_IoT-Sentinel/D-LinkSiren/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-16-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-17-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-A-9-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-4-STA_FE.csv', 
            'captures_IoT-Sentinel/Lightify/Setup-C-19-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-20-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-3-STA_FE.csv',
            'captures_IoT-Sentinel/HueBridge/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-4-STA_FE.csv',
            'captures_IoT-Sentinel/EdnetGateway/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-13-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-14-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-15-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-16-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-19-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-20-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch2/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch2/Setup-C-3-STA_FE.csv',
            'captures_IoT-Sentinel/D-LinkCam/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-2-STA_FE.csv',
            'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-2-STA_FE.csv', 
            'captures_IoT-Sentinel/SmarterCoffee/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-8-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-A-9-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-4-STA_FE.csv',
            'captures_IoT-Sentinel/WeMoLink/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-6-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-7-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-8-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-A-9-STA_FE.csv', 
            'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-9-STA_FE.csv',
            'captures_IoT-Sentinel/MAXGateway/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch2/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch2/Setup-C-2-STA_FE.csv']

# %%
test=[ 'captures_IoT-Sentinel/Aria/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/Aria/Setup-C-9-STA_FE.csv',
      'captures_IoT-Sentinel/Withings/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/Withings/Setup-C-9-STA_FE.csv', 
      'captures_IoT-Sentinel/WeMoSwitch/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch/Setup-C-6-STA_FE.csv', 
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkCam/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch2/Setup-C-4-STA_FE.csv', 
      'captures_IoT-Sentinel/EdnetCam2/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-C-7-STA_FE.csv', 
      'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug1101W/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxPlug2101W/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetCam2/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-C-3-STA_FE.csv',
      'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch2/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch2/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoInsightSwitch2/Setup-C-5-STA_FE.csv', 
 'captures_IoT-Sentinel/iKettle2/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-C-4-STA_FE.csv',
      'captures_IoT-Sentinel/D-LinkDayCam/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDayCam/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-6-STA_FE.csv', 
      'captures_IoT-Sentinel/D-LinkHomeHub/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkHomeHub/Setup-A-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-5-STA_FE.csv', 
      'captures_IoT-Sentinel/D-LinkSiren/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSiren/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSwitch/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkSensor/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkDoorSensor/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/iKettle2/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS110/Setup-C-9-STA_FE.csv', 
      'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/TP-LinkPlugHS100/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-7-STA_FE.csv', 
      'captures_IoT-Sentinel/EdnetGateway/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/EdnetGateway/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/HomeMaticPlug/Setup-C-9-STA_FE.csv',
      'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-10-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-11-STA_FE.csv',
 'captures_IoT-Sentinel/D-LinkWaterSensor/Setup-C-12-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-C-1-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/EdimaxCam2/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/MAXGateway/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-C-2-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-C-3-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/SmarterCoffee/Setup-C-5-STA_FE.csv', 
      'captures_IoT-Sentinel/Lightify/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/Lightify/Setup-C-9-STA_FE.csv', 
      'captures_IoT-Sentinel/HueBridge/Setup-A-1-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-A-2-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-A-3-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-A-4-STA_FE.csv',
 'captures_IoT-Sentinel/HueBridge/Setup-A-5-STA_FE.csv',
'captures_IoT-Sentinel/HueSwitch/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-6-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-7-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-8-STA_FE.csv',
 'captures_IoT-Sentinel/HueSwitch/Setup-C-9-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-C-4-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoLink/Setup-C-5-STA_FE.csv',
 'captures_IoT-Sentinel/WeMoSwitch2/Setup-C-5-STA_FE.csv']

# %%
df_list={"Train_IoTDevID.csv":train,"Validation_IoTDevID.csv":validation,"Test_IoTDevID.csv":test}

for name in df_list:

    df=pd.read_csv(df_list[name][0])
    col_names=list(df.columns)
    empty = pd.DataFrame(columns=col_names)
    empty.to_csv(name, mode="w", index=False)#,header=False)
    for iii in tqdm(df_list[name]):
        df=pd.read_csv(iii)
        df.to_csv(name, mode="a", index=False,header=False)
        df=pd.read_csv(name)
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:23<00:00,  5.86it/s]

# %%
col= ['pck_size', 'Ether_type', 'LLC_ctrl', 'EAPOL_version', 'EAPOL_type', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'IP_DF', 'IP_ttl', 'IP_options', 'ICMP_code', 'TCP_dataofs', 'TCP_FIN', 'TCP_ACK', 'TCP_window', 'UDP_len', 'DHCP_options', 'BOOTP_hlen', 'BOOTP_flags', 'BOOTP_sname', 'BOOTP_file', 'BOOTP_options', 'DNS_qr', 'DNS_rd', 'DNS_qdcount', 'dport_class', 'payload_bytes', 'entropy',
"MAC",'Label']

for i in df_list:
    print(i)
    df=pd.read_csv(i,usecols=col)
    df=df[df["Label"]!="unknown"]
    df.to_csv(i,index=False)
    flag_fixer(i)
    print(df.groupby("Label").size())
# Out:
# Train_IoTDevID.csv
# Label
# Aria                  220
# D-LinkCam            3777
# D-LinkDayCam          533
# D-LinkDoorSensor      969
# D-LinkHomeHub        5007
# D-LinkSensor         3417
# D-LinkSiren          3141
# D-LinkSwitch         3264
# D-LinkWaterSensor    3183
# EdimaxCam             411
# EdimaxPlug1101W       660
# EdimaxPlug2101W       432
# EdnetCam              177
# EdnetGateway          335
# HomeMaticPlug         170
# HueBridge            6829
# HueSwitch            9456
# Lightify             1970
# MAXGateway            293
# SmarterCoffee          53
# TP-LinkPlugHS100      328
# TP-LinkPlugHS110      315
# WeMoInsightSwitch    2744
# WeMoLink             3207
# WeMoSwitch           2403
# Withings              333
# iKettle2               53
# dtype: int64
# Validation_IoTDevID.csv
# Label
# Aria                  111
# D-LinkCam            1252
# D-LinkDayCam          266
# D-LinkDoorSensor      423
# D-LinkHomeHub        1767
# ...
