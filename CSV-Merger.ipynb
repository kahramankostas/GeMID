# %%
import os
from tqdm import tqdm
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add
path="./csv/"
files_add=find_the_way(path,'.csv')
files_add
# Out:
# ['./csv/pcaps-Aria-Setup-A-1-STA.csv',
#  './csv/pcaps-Aria-Setup-A-2-STA.csv',
#  './csv/pcaps-Aria-Setup-A-3-STA.csv',
#  './csv/pcaps-Aria-Setup-A-4-STA.csv',
#  './csv/pcaps-Aria-Setup-A-5-STA.csv',
#  './csv/pcaps-Aria-Setup-C-1-STA.csv',
#  './csv/pcaps-Aria-Setup-C-10-STA.csv',
#  './csv/pcaps-Aria-Setup-C-11-STA.csv',
#  './csv/pcaps-Aria-Setup-C-12-STA.csv',
#  './csv/pcaps-Aria-Setup-C-13-STA.csv',
#  './csv/pcaps-Aria-Setup-C-14-STA.csv',
#  './csv/pcaps-Aria-Setup-C-15-STA.csv',
#  './csv/pcaps-Aria-Setup-C-2-STA.csv',
#  './csv/pcaps-Aria-Setup-C-3-STA.csv',
#  './csv/pcaps-Aria-Setup-C-4-STA.csv',
#  './csv/pcaps-Aria-Setup-C-5-STA.csv',
#  './csv/pcaps-Aria-Setup-C-6-STA.csv',
#  './csv/pcaps-Aria-Setup-C-7-STA.csv',
#  './csv/pcaps-Aria-Setup-C-8-STA.csv',
#  './csv/pcaps-Aria-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-A-1-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-A-2-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-A-3-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-A-4-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-A-5-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-B-1-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-B-2-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-B-3-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-B-4-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-B-5-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkCam-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-A-1-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-A-2-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-A-3-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-A-4-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-A-5-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-11-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-12-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-13-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-14-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-15-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkDayCam-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-11-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-12-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-13-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-14-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-15-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-16-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-17-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-18-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-19-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-20-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkDoorSensor-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-A-1-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-A-2-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-A-3-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-A-4-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-A-5-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-11-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-12-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-13-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-14-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-15-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkHomeHub-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-A-1-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-A-2-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-A-3-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-A-4-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-A-5-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-B-1-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-B-2-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-B-3-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-B-4-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-B-5-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkSensor-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-A-1-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-11-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-12-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-13-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-14-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-15-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-16-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-17-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-18-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-19-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkSiren-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-A-1-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-A-2-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-A-3-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-A-4-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-A-5-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-11-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-12-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-13-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-14-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-15-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkSwitch-Setup-C-9-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-A-1-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-1-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-10-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-11-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-12-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-13-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-14-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-15-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-16-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-17-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-18-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-19-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-2-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-3-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-4-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-5-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-6-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-7-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-8-STA.csv',
#  './csv/pcaps-D-LinkWaterSensor-Setup-C-9-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-A-1-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-A-2-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-A-3-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-A-4-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-A-5-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-A-6-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-A-7-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-C-1-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-C-2-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-C-3-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-C-4-STA.csv',
#  './csv/pcaps-EdimaxCam1-Setup-C-5-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-A-1-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-A-2-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-A-3-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-A-4-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-C-1-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-C-2-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-C-3-STA.csv',
#  './csv/pcaps-EdimaxCam2-Setup-C-4-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-A-1-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-A-2-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-A-3-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-A-4-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-A-5-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-1-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-10-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-11-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-12-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-13-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-14-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-15-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-2-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-3-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-4-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-5-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-6-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-7-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-8-STA.csv',
#  './csv/pcaps-EdimaxPlug1101W-Setup-C-9-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-A-1-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-A-2-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-A-3-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-A-4-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-A-5-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-1-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-10-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-11-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-12-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-13-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-14-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-15-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-2-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-3-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-4-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-5-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-6-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-7-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-8-STA.csv',
#  './csv/pcaps-EdimaxPlug2101W-Setup-C-9-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-A-1-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-1-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-10-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-2-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-3-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-4-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-5-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-6-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-7-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-8-STA.csv',
#  './csv/pcaps-EdnetCam1-Setup-C-9-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-A-1-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-1-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-2-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-3-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-4-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-5-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-6-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-7-STA.csv',
#  './csv/pcaps-EdnetCam2-Setup-C-8-STA.csv',
#  './csv/pcaps-EdnetGateway-Setup-A-1-STA.csv',
#  './csv/pcaps-EdnetGateway-Setup
STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-2-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-3-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-4-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-5-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-6-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-7-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-8-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-A-9-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-1-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-2-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-3-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-4-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-5-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-6-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-7-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-8-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch-Setup-C-9-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch2-Setup-C-1-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch2-Setup-C-2-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch2-Setup-C-3-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch2-Setup-C-4-STA.csv',
#  './csv/pcaps-WeMoInsightSwitch2-Setup-C-5-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-1-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-10-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-11-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-12-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-13-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-14-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-15-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-2-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-3-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-4-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-5-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-6-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-7-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-8-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-A-9-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-C-1-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-C-2-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-C-3-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-C-4-STA.csv',
#  './csv/pcaps-WeMoLink-Setup-C-5-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-1-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-10-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-2-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-3-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-4-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-5-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-6-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-7-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-8-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-A-9-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-1-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-10-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-2-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-3-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-4-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-5-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-6-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-7-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-8-STA.csv',
#  './csv/pcaps-WeMoSwitch-Setup-C-9-STA.csv',
#  './csv/pcaps-WeMoSwitch2-Setup-C-1-STA.csv',
#  './csv/pcaps-WeMoSwitch2-Setup-C-2-STA.csv',
#  './csv/pcaps-WeMoSwitch2-Setup-C-3-STA.csv',
#  './csv/pcaps-WeMoSwitch2-Setup-C-4-STA.csv',
#  './csv/pcaps-WeMoSwitch2-Setup-C-5-STA.csv',
#  './csv/pcaps-Withings-Setup-A-1-STA.csv',
#  './csv/pcaps-Withings-Setup-C-1-STA.csv',
#  './csv/pcaps-Withings-Setup-C-10-STA.csv',
#  './csv/pcaps-Withings-Setup-C-11-STA.csv',
#  './csv/pcaps-Withings-Setup-C-12-STA.csv',
#  './csv/pcaps-Withings-Setup-C-13-STA.csv',
#  './csv/pcaps-Withings-Setup-C-14-STA.csv',
#  './csv/pcaps-Withings-Setup-C-15-STA.csv',
#  './csv/pcaps-Withings-Setup-C-16-STA.csv',
#  './csv/pcaps-Withings-Setup-C-17-STA.csv',
#  './csv/pcaps-Withings-Setup-C-18-STA.csv',
#  './csv/pcaps-Withings-Setup-C-19-STA.csv',
#  './csv/pcaps-Withings-Setup-C-2-STA.csv',
#  './csv/pcaps-Withings-Setup-C-3-STA.csv',
#  './csv/pcaps-Withings-Setup-C-4-STA.csv',
#  './csv/pcaps-Withings-Setup-C-5-STA.csv',
#  './csv/pcaps-Withings-Setup-C-6-STA.csv',
#  './csv/pcaps-Withings-Setup-C-7-STA.csv',
#  './csv/pcaps-Withings-Setup-C-8-STA.csv',
#  './csv/pcaps-Withings-Setup-C-9-STA.csv']

# %%
essiz=[]
for i in  tqdm(files_add):
    df=pd.read_csv(i)
    for ii in df.columns:
        if ii not in essiz:
            essiz.append(ii)
            
len(essiz)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 550/550 [00:24<00:00, 22.86it/s]
# 667

# %%
flag=0
for i in  tqdm(files_add):
        df = pd.DataFrame(columns=essiz)
        ek=pd.read_csv(i)

        result = pd.concat([df, ek], ignore_index=True, sort=False)
        result.to_csv(i, index=False)
        #result.to_csv(f"nihai{flag}.csv", index=False)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 550/550 [01:46<00:00,  5.14it/s]
